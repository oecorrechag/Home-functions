# %%
import shap
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
from sklearn.datasets import fetch_california_housing

# %%
# California Housing Prices
dataset = fetch_california_housing(as_frame = True)
X = dataset['data']
y = dataset['target']

# %%
X = X.iloc[0:500]
y = y.iloc[0:500]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
# Prepares a default instance of the random forest regressor
model = RandomForestRegressor()
# Fits the model on the data
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Prepares a default instance of the random forest regressor
model = RandomForestRegressor()

# %%
# Fits the model on the data
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Fits the explainer
explainer = shap.Explainer(model.predict, X_test)

# %%
# Calculates the SHAP values - It takes some time
shap_values = explainer(X_test)
# Out:
# Exact explainer: 101it [00:21,  2.51it/s]

# %%
# Evaluate SHAP values
shap_values = explainer.shap_values(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1880/124736348.py in <module>
#       1 # Evaluate SHAP values
# ----> 2 shap_values = explainer.shap_values(X)
#
# AttributeError: 'Exact' object has no attribute 'shap_values'

# %%
shap.plots.bar(shap_values)

# %%
shap.summary_plot(shap_values)

# %%
# or 
shap.plots.beeswarm(shap_values)

# %%
shap.summary_plot(shap_values, plot_type='violin')

# %%
shap.plots.bar(shap_values[0])

# %%
shap.plots.waterfall(shap_values[0])

# %%
shap.plots.force(shap_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1880/3437554419.py in <module>
# ----> 1 shap.plots.force(shap_test)
#
# NameError: name 'shap_test' is not defined
