# %%
import pandas as pd
import numpy as np

# %%
lista_latitudes = [4.577801021881366,4.591025578552886,4.6425515990044115,4.618487351262866,4.631764206804927, 
                   4.652324435764624, 4.618771605675896, 4.642706923026336,
                   4.749965206845706, 4.732497498791747, 4.688040563308064, 4.712237791416967, 4.711475130840443,
                   4.646363672228067, 4.651335558506142, 4.66381673212429, 4.710718089691377, 4.682927641545739, 4.64777778, 4.6916066524526165, 4.653270449580609, 4.666641336418658, 4.666153607718665, 4.666026356139215, 4.656838661505203, 4.762980200587227, 4.6935465888775125, 4.716094354924267, 4.70173616237123, 4.73212229183283, 4.690978584058933, 4.736179930291981,
                   4.588478580669053, 
                  ]

lista_longitudes = [-74.1302861263075, -74.12427554225071, -74.15646560611846, -74.13533707793628, -74.11577637804815, 
                    -74.12571878629174, -74.08640172015834, -74.0747228284098,
                    -74.09632279774667, -74.06677749165567, -74.0643080365637, -74.07145834317453, -74.07275926277701,
                    -74.12821748326516, -74.10634229045671, -74.12988202441682, -74.1116929372334, -74.1166444394937, -74.10138889, -74.07490944915335, -74.10990566595817, -74.05341878456537, -74.05427464014616, -74.05587732951138, -74.05777055467662, -74.04685726838947, -74.03282320181573, -74.0292353173722, -74.0412400658832, -74.04247001468286, -74.03663231673788, -74.04978563249422,
                    -74.2047372238657, 
                   ]

lista_nombres = ['Centro Comercial Ciudad Tunal', 'Centro Comercial Centro Mayor', 'Centro Comercial El Tintal', 'Centro Comercial Plaza de las Americas', 'Centro Comercial Plaza Central',
                 'Centro Comercial MultiPlaza', 'Centro Comercial Calima Plaza', 'Centro Comercial Galerias',
                 'Centro Comercial Imperial Plaza', 'Centro Comercial Colina', 'Centro Comercial Iserra 100', 'Centro Comercial Bulevar Niza', 'Centro Comercial Niza',
                 'Centro Comercial EL Eden', 'Centro Comercial Plaza Claro', 'Centro Comercial Hayuelos', 'Centro Comercial Portal de la 80', 'Centro Comercial Nuestro Bogota', 'Centro Comercial Gran estación', 'Centro Comercial Floresta', 'Centro Comercial Salitre Plaza', 'Centro Comercial Centro Andino', 'Centro Comercial El Retiro', 'Centro Comercial Atlantis Plaza', 'Centro Comercial Avenida Chile', 'Centro Comercial Santa Fe', 'Centro Comercial Hacienda Santa barbara', 'Centro Comercial Palatino', 'Centro Comercial Unicentro', 'Centro Comercial Cedritos', 'Centro Comercial Santa Ana', 'Centro Comercial Mazurem',
                 'Centro Comercial Mercurio'
                ]

# %%
cc = {'centroComercial': lista_nombres,
      'latitud': lista_latitudes,
      'longitud': lista_longitudes
     }

# %%
cc = pd.DataFrame.from_dict(cc)
cc
# Out:
#                             centroComercial   latitud   longitud
# 0             Centro Comercial Ciudad Tunal  4.577801 -74.130286
# 1             Centro Comercial Centro Mayor  4.591026 -74.124276
# 2                Centro Comercial El Tintal  4.642552 -74.156466
# 3    Centro Comercial Plaza de las Americas  4.618487 -74.135337
# 4            Centro Comercial Plaza Central  4.631764 -74.115776
# 5               Centro Comercial MultiPlaza  4.652324 -74.125719
# 6             Centro Comercial Calima Plaza  4.618772 -74.086402
# 7                 Centro Comercial Galerias  4.642707 -74.074723
# 8           Centro Comercial Imperial Plaza  4.749965 -74.096323
# 9                   Centro Comercial Colina  4.732497 -74.066777
# 10              Centro Comercial Iserra 100  4.688041 -74.064308
# 11            Centro Comercial Bulevar Niza  4.712238 -74.071458
# 12                    Centro Comercial Niza  4.711475 -74.072759
# ...

# %%
cc.to_csv('centrosComerciales.csv', encoding = 'utf-8-sig', index = False)
